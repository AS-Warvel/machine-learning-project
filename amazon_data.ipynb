# %%
import pandas as pd

df = pd.read_csv('Datasets/CSVs/amazon.csv')

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['img_link', 'product_link'])
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# <h4>Columns:-</h4>
# product_id
# <br>product_name
# <br>category
# <br>discounted_price
# <br>actual_price
# <br>discount_percentage
# <br>rating
# <br>about_product
# <br>rating_count
# <br>user_id
# <br>user_name
# <br>review_id
# <br>review_title
# <br>review_content

# %%
df.duplicated().sum()
# Out:
# np.int64(65)

# %%
df.drop_duplicates(inplace=True)

# %%
columns = df.columns
for col in columns:
    print(col,": ",df[col].isnull().sum())
# Out:
# product_id :  0
# product_name :  0
# category :  0
# discounted_price :  0
# actual_price :  0
# discount_percentage :  0
# rating :  0
# rating_count :  2
# about_product :  0
# user_id :  0
# user_name :  0
# review_id :  0
# review_title :  0
# review_content :  0

# %%
df.dropna(inplace=True)

# %%
columns = df.columns
for col in columns:
    print(col,": ",df[col].isnull().sum())
# Out:
# product_id :  0
# product_name :  0
# category :  0
# discounted_price :  0
# actual_price :  0
# discount_percentage :  0
# rating :  0
# rating_count :  0
# about_product :  0
# user_id :  0
# user_name :  0
# review_id :  0
# review_title :  0
# review_content :  0

# %%
columns = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  49
# product_name :  63
# about_product :  107
# user_id :  206
# review_content :  188
# review_id :  206

# %%
df.drop_duplicates(subset="review_content",inplace=True)

# %%
columns = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  15
# product_name :  16
# about_product :  31
# user_id :  18
# review_content :  0
# review_id :  18

# %%
df.drop_duplicates(subset="about_product",inplace=True)

# %%
olumnsc = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  1
# product_name :  2
# about_product :  0
# user_id :  10
# review_content :  0
# review_id :  10

# %%
df2 = df[df.duplicated(subset="product_name", keep=False)]
df2
# Out:
#      product_id                                       product_name  \
# 2    B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 79   B0BCZCQTJX                                   Firestick Remote
# 290  B09TY4MSH3                                   Firestick Remote
# 379  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                               category discounted_price  \
# 2    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 79   Electronics|HomeTheater,TV&Video|Accessories|R...           ₹1,434
# 290  Electronics|HomeTheater,TV&Video|Accessories|R...           ₹1,289
# 379  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#     actual_price discount_percentage rating rating_count  \
# 2         ₹1,899                 90%    3.9        7,928
# 79        ₹3,999                 64%    4.0           32
# 290       ₹2,499                 48%    3.3           73
# ...

# %%
df.drop_duplicates(subset="product_id",inplace=True)

# %%
columns = ['product_id','product_name','about_product','user_id','review_title','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  0
# product_name :  1
# about_product :  0
# user_id :  9
# review_title :  9
# review_content :  0
# review_id :  9

# %%
df2 = df[df.duplicated(subset="review_id", keep=False)]
df2
# Out:
#      product_id                                       product_name  \
# 0    B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 5    B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 16   B0B6F7LX4C  MI 80 cm (32 inches) 5A Series HD Ready Smart ...
# 23   B09NHVCHS9        Flix Micro Usb Cable For Smartphone (Black)
# 35   B08Y1SJVV5  pTron Solero MB301 3A Micro USB Data & Chargin...
# 53   B07MKFNHKG  VW 80 cm (32 inches) Frameless Series HD Ready...
# 80   B07LGT55SJ  Wayona Usb Nylon Braided Data Sync And Chargin...
# 81   B09NKZXMWJ  Flix (Beetel) Usb To Type C Pvc Data Sync And ...
# 89   B07JH1C41D  Wayona Nylon Braided (2 Pack) Lightning Fast U...
# 103  B0B6F98KJJ  MI 100 cm (40 inches) 5A Series Full HD Smart ...
# 109  B08Y5KXR6Z  PTron Solero T241 2.4A Type-C Data & Charging ...
# 176  B0B3N8VG24  FLiX (Beetel USB to Type C PVC Data Sync & 15W...
# 190  B07MDRGHWQ  VW 60 cm (24 inches) Premium Series HD Ready L...
# ...

# %% [markdown]
# Review title and review content are also same where review_id and user_id are same, hence they are duplicated
