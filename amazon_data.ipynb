# %%
import pandas as pd

df = pd.read_csv('Datasets/CSVs/amazon.csv')

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['img_link', 'product_link'])
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# <h4>Columns:-</h4>
# product_id
# <br>product_name
# <br>category
# <br>discounted_price
# <br>actual_price
# <br>discount_percentage
# <br>rating
# <br>about_product
# <br>rating_count
# <br>user_id
# <br>user_name
# <br>review_id
# <br>review_title
# <br>review_content

# %%
df.duplicated().sum()
# Out:
# np.int64(65)

# %%
df.drop_duplicates(inplace=True)

# %%
columns = df.columns
for col in columns:
    print(col,": ",df[col].isnull().sum())
# Out:
# product_id :  0
# product_name :  0
# category :  0
# discounted_price :  0
# actual_price :  0
# discount_percentage :  0
# rating :  0
# rating_count :  2
# about_product :  0
# user_id :  0
# user_name :  0
# review_id :  0
# review_title :  0
# review_content :  0

# %%
columns = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  49
# product_name :  63
# about_product :  107
# user_id :  206
# review_content :  188
# review_id :  206

# %%
df2 = df[df["product_id"].duplicated(keep=False)]

s = df2.sort_values(by="product_id")
s
# Out:
#      product_id                                       product_name  \
# 833  B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 33   B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 852  B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 40   B00NH11KIK  AmazonBasics USB 2.0 Cable - A-Male to B-Male ...
# 347  B01DEWVZ2C  JBL C100SI Wired In Ear Headphones with Mic, J...
# ..          ...                                                ...
# 344  B0B5LVS732  Noise Pulse Go Buzz Smart Watch Bluetooth Call...
# 70   B0B86CDHL1  oraimo 65W Type C to C Fast Charging Cable USB...
# 979  B0B86CDHL1  oraimo 65W Type C to C Fast Charging Cable USB...
# 343  B0BDRVFDKP  SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 14...
# 593  B0BDRVFDKP  SanDisk Ultra® microSDXC™ UHS-I Card, 64GB, 14...
#
#                                               category discounted_price  \
# 833  Computers&Accessories|Accessories&Peripherals|...             ₹599
# ...

# %%
df3 = df[df["product_id"] == "B008FWZGSG"]
for col in df.columns:
    if(df3[col][33] == df3[col][833]):
        print(col, " : ", "True")
    else:
        print(col, " : ", "False")
# df3["product_id"]
# Out:
# product_id  :  True
# product_name  :  True
# category  :  True
# discounted_price  :  True
# actual_price  :  True
# discount_percentage  :  True
# rating  :  True
# rating_count  :  True
# about_product  :  True
# user_id  :  True
# user_name  :  True
# review_id  :  True
# review_title  :  True
# review_content  :  False

# %%
s1 = df3["review_content"][33]

# %%
s2 = df3["review_content"][833]

# %%
if len(s1) < len(s2):
    l = len(s1)
else:
    l = len(s2)
for i in range(l):
    if(s1[i] != s2[i]):
        print(i, " ", s1[i], " ", s2[i])
# Out:
# 253   W   I
# 255   W   7
# 256   E   1
# 257   B   C
# 258   P   E
# 259   _   I
# 260   4   3
# 261   0   G
# 262   2   +
# 263   3   B
# 264   7   L
# 265   8   L
# 266   -   .
# 267   T   _
# 268   1   S
# 269   /   Y
# 270   i   8
# 271   m   8
# 272   a   .
# 273   g   j
# 274   e   p
# 275   s   g
# 276   /   ,
# 277   I   T
# 278   /   h
# 279   7   e
# 280   1
# 281   C   c
# 282   E   a
# 283   I   b
# 284   3   l
# 285   G   e
# 286   +
# 287   B   i
# 288   L   s
# 289   L
# 290   .   p
# 291   _   e
# 292   S   r
# 293   Y   f
# 294   8   e
# 295   8   c
# 296   .   t
# 297   j
# 298   p   f
# 299   g   o
# 300   ,   r
# 301   T
# 302   h   3
# 303   e   A
# 306   a   h
# 307   b   a
# 308   l   r
# 309   e   g
# 310       i
# 311   i   n
# 312   s   g
# 314   p   d
# 316   r   v
# 317   f   i
# 318   e   c
# 319   c   e
# 320   t   s
# 322   f   .
# 323   o
# 324   r   S
# 325       u
# 326   3   p
# 327   A   p
# 328       o
# 329   c   r
# 330   h   t
# 331   a
# ...

# %%
s1[1] == s2[1]
# Out:
# True

# %%
columns = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  49
# product_name :  63
# about_product :  107
# user_id :  206
# review_content :  188
# review_id :  206

# %%
df = df.drop_duplicates(subset="product_id")

# %%
columns = ['product_id','product_name','about_product','user_id','review_content', 'review_id']
for col in columns:
    print(col,": ",df[col].duplicated().sum())
# Out:
# product_id :  0
# product_name :  14
# about_product :  61
# user_id :  165
# review_content :  154
# review_id :  165

# %%
df[df["product_name"].duplicated(keep=False)].sort_values(by="product_name")
# Out:
#      product_id                                       product_name  \
# 484  B09YV3K34W  Fire-Boltt India's No 1 Smartwatch Brand Talk ...
# 365  B09YV4MW2T  Fire-Boltt India's No 1 Smartwatch Brand Talk ...
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 364  B0BF54972T  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380  B0BF54LXW6  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368  B0BF563HB4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 372  B0BF4YBLPX  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 508  B0B3RS9DNF  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 385  B0B3RSDSZ3  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 335  B0B3RRWSF6  Fire-Boltt Phoenix Smart Watch with Bluetooth ...
# 375  B0B3N7LR6K  Fire-Boltt Visionary 1.78" AMOLED Bluetooth Ca...
# 574  B0B3NDPCS9  Fire-Boltt Visionary 1.78" AMOLED Bluetooth Ca...
# 290  B09TY4MSH3                                   Firestick Remote
# ...

# %%
# dup_reviews = df['review_content'].duplicated()
# for i in dup_reviews:
    # print(i)
# df = df['review_content'].drop_duplicates()
# df
dup_reviews = df['review_content'].drop_duplicates()
dup_reviews.index[1200]
# Out:
# np.int64(1453)

# %%
duplicates = df['product_id'].duplicated()
for i in range(len(duplicates)):
    if(duplicates[i] == True):     
        print(df.iloc[i:i+1,1:3])
        # print(df[i])
        print()
# for j in indices:
    # df[['review_id', 'user_id']][j]
# for i,j in df[['review_id', 'user_id']], duplicates:
    # if(j == True):
        # print(i)
# Out:
#                                           product_name  \
# 369  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                               category
# 369  Computers&Accessories|Accessories&Peripherals|...
#
#                                           product_name  \
# 377  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                               category
# 377  Computers&Accessories|Accessories&Peripherals|...
#
#                                           product_name  \
# 379  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                               category
# 379  Computers&Accessories|Accessories&Peripherals|...
#
#                                           product_name  \
# 392  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#                                               category
# 392  Computers&Accessories|Accessories&Peripherals|...
# ...
